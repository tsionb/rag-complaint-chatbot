# %%
# Out:
# 'C:\\Users\\DELL\\Desktop\\10X-Academy\\10academy-week7\\rag-complaint-chatbot\\notebooks'

# %%
import os

os.listdir("data/raw")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 os.listdir("data/raw")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/raw'
